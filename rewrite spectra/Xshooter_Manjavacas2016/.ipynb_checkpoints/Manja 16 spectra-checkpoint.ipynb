# %%
#2M0036_total.fits

# %%
import astropy
import seaborn as sns
from astropy.io import fits
fits_image_filename = astropy.io.fits.open('2M0036_total.fits')
hdul = fits.open('2M0036_total.fits')

data = hdul[0].data
header = hdul[0].header

print(data)
# Out:
# [[5.33679993e+02 0.00000000e+00 0.00000000e+00]
#  [5.33719971e+02 0.00000000e+00 0.00000000e+00]
#  [5.33760010e+02 0.00000000e+00 0.00000000e+00]
#  ...
#  [2.47889990e+03 7.44981674e-15 8.05883451e-16]
#  [2.47895996e+03 8.18882046e-15 8.07036528e-16]
#  [2.47902002e+03 9.74981092e-15 0.00000000e+00]]

# %%
list(header.keys())
# Out:
# ['SIMPLE',
#  'BITPIX',
#  'NAXIS',
#  'NAXIS1',
#  'NAXIS2',
#  'EXTEND',
#  'DATE',
#  'COMMENT',
#  'COMMENT']

# %%
from glob import glob
import astropy.io.fits as pyfits
from matplotlib import pyplot as plt

files = glob('*.fits')
#fits_data_dir = 'pngs/'

for file_name in files:
    data = pyfits.getdata(file_name)
    name = file_name[:-len('.fits')] # Remove .fits from the file name

    plt.errorbar(data[:,0], data[:,1], data[:,2])

    plt.title(name)

    plt.show()
