# %%
import warnings
warnings.filterwarnings('ignore')
from astropy import units as u
from convertfits import *
import pandas as pd

# %%
table_file = 'IRS Spectrum - Daniel  - Sheet1.csv'
meta_data_table= 'suarez2022_table.txt'


spectra_data_info = {
    'data' : Table.read(table_file),
    'meta_data' : open(meta_data_table, 'r'),
    'original_data_dir' : 'IRS_Spectra_of_113_Field_M5-T9_Dwarfs_in_Suarez-Metchev2022/',
    'fits_data_dir' : 'Suarez2022/',
    'wavelength_unit' : u.micron ,
    'flux_unit' : u.Jy,
    'bandpass' : None, #wavelenght range
    'aperture' : None,
    'vopub' : 'SIMPLE Archive',
    'voclass' : None, #set , corresponds to IVOA data model
    'title' : 'IRS Spectra of Brown Dwarfs from Suarez & Metchev 2022',
    'bibcode' : '2022MNRAS.513.5701S' ,
    'author' : 'Suarez, Genaro; Metchev, Stanimir',
    'doi' : ' 10.1093/mnras/stac1205' ,
    'generated_history' : 'This file generated by SIMPLE-db/scripts/ingests/rewrite_spectra.py',
    'spectra_comments' : None ,
    'flux_column' : 'col2',
    "flux_unc_column" : 'col3',
    "wavelength_column" : 'col1',
    "object_name_column" : 'Source',
    "spectrum_url_column" : 'Spectrum',
    "RA_column_name" : 'RA',
    "dec_column_name" : 'dec',
    "start_time_column_name " : 'start time',
    "stop_time_column_name " : 'stop time',
    "exposure_time_column_name" : 'exposure time',
    "instrument_column_name" : 'instrument',
    "observation_date_column_name" : 'observation_date',
    "telescope_column_name" : 'telescope',
    "startline" : None,
    "obs_location": None
    }

# %%
convert_to_fits(spectra_data_info)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 convert_to_fits(spectra_data_info)
#
# File ~/gitlocation/rewrite spectra/convertfits.py:32, in convert_to_fits(spectra_data_info)
#      29 comment1 = spectra_data_info['spectra_comments']
#      30 comment = (comment1)
# ---> 32 spectrum_table = create_spectrum_table(spectrum_url, spectra_data_info['startline'])
#      34 wavelength_data = spectrum_table[spectra_data_info['wavelength_column']] * spectra_data_info['wavelength_unit']
#      35 #wavelength, flux = np.empty(0), np.empty(0)
#
# File ~/gitlocation/rewrite spectra/create_spectrum_table.py:12, in create_spectrum_table(spectrum_url, startline)
#      10 file_root = os.path.splitext(file)[1]
#      11 if file_root == '.dat':
# ---> 12     spectrum_table = Table.read(spectrum_url, format='ascii',names=['col1', 'col2', 'col3'])
#      13 elif file_root == '.fits':
#      14     url_data = fits.getdata(spectrum_url)
#
# File ~/opt/anaconda3/envs/simple-db/lib/python3.9/site-packages/astropy/table/connect.py:62, in TableRead.__call__(self, *args, **kwargs)
#      59 units = kwargs.pop('units', None)
#      60 descriptions = kwargs.pop('descriptions', None)
# ---> 62 out = self.registry.read(cls, *args, **kwargs)
#      64 # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#      65 # guaranteed to be the same as the desired output `cls`.  If so,
#      66 # try coercing to desired class without copying (io.registry.read
#      67 # would normally do a copy).  The normal case here is swapping
#      68 # Table <=> QTable.
#      69 if cls is not out.__class__:
#
# File ~/opt/anaconda3/envs/simple-db/lib/python3.9/site-packages/astropy/io/registry/core.py:212, in UnifiedInputRegistry.read(self, cls, format, cache, *args, **kwargs)
#     208     format = self._get_valid_format(
#     209         'read', cls, path, fileobj, args, kwargs)
#     211 reader = self.get_reader(format, cls)
# --> 212 data = reader(*args, **kwargs)
#     214 if not isinstance(data, cls):
#     215     # User has read with a subclass where only the parent class is
#     216     # registered.  This returns the parent class, so try coercing
#     217     # to desired subclass.
#     218     try:
#
# File ~/opt/anaconda3/envs/simple-db/lib/python3.9/site-packages/astropy/io/ascii/connect.py:18, in io_read(format, filename, **kwargs)
#      16     format = re.sub(r'^ascii\.', '', format)
#      17     kwargs['format'] = format
# ---> 18 return read(filename, **kwargs)
#
# File ~/opt/anaconda3/envs/simple-db/lib/python3.9/site-packages/astropy/io/ascii/ui.py:359, in read(table, guess, **kwargs)
#     353             new_kwargs['guess_html'] = _probably_html(table)
#     355 # Get the table from guess in ``dat``.  If ``dat`` comes back as None
#     356 # then there was just one set of kwargs in the guess list so fall
#     357 # through below to the non-guess way so that any problems result in a
#     358 # more useful traceback.
# --> 359 dat = _guess(table, new_kwargs, format, fast_reader)
#     360 if dat is None:
#     361     guess = False
#
# File ~/opt/anaconda3/envs/simple-db/lib/python3.9/site-packages/astropy/io/ascii/ui.py:526, in _guess(table, read_kwargs, format, fast_reader)
#     523 reader = get_reader(**guess_kwargs)
#     525 reader.guessing = True
# --> 526 dat = reader.read(table)
#     527 _read_trace.append({'kwargs': copy.deepcopy(guess_kwargs),
#     528                     'Reader': reader.__class__,
#     529                     'status': 'Success (guessing)',
#     530                     'dt': f'{(time.time() - t0) * 1000:.3f} ms'})
#     531 return dat
#
# File ~/opt/anaconda3/envs/simple-db/lib/python3.9/site-packages/astropy/io/ascii/fastbasic.py:109, in FastBasic.read(self, table)
#     106 # Put fast_reader dict back into kwargs.
#     107 self.kwargs['fast_reader'] = fast_reader
# --> 109 self.engine = cparser.CParser(table, self.strip_whitespace_lines,
#     110                               self.strip_whitespace_fields,
#     111                               delimiter=self.delimiter,
#     112                               header_start=self.header_start,
#     113                               comment=self.comment,
#     114                               quotechar=self.quotechar,
#     115                               data_start=self.data_start,
#     116                               fill_extra_cols=self.fill_extra_cols,
#     117                               **self.kwargs)
#     118 conversion_info = self._read_header()
#     119 self.check_header()
#
# File astropy/io/ascii/cparser.pyx:248, in astropy.io.ascii.cparser.CParser.__cinit__()
#
# File astropy/io/ascii/cparser.pyx:296, in astropy.io.ascii.cparser.CParser.setup_tokenizer()
#
# File astropy/io/ascii/cparser.pyx:124, in astropy.io.ascii.cparser.FileString.__cinit__()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://bdnyc.s3.amazonaws.com/IRS/0036%2B1821_IRS_spectrum.dat'
